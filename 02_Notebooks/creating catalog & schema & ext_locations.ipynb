# %% [markdown]
# **Creating Catalog**

# %%
# %sql
CREATE CATALOG if not exists t20_catalog;

# %% [markdown]
# **Creating Schema**

# %%
# %sql
CREATE SCHEMA if not exists t20_catalog.bronze;

# %%
# %sql
CREATE SCHEMA if not exists t20_catalog.silver;

# %%
# %sql
CREATE SCHEMA if not exists t20_catalog.gold;

# %% [markdown]
# Creating external Location

# %%
# %sql
CREATE EXTERNAL LOCATION bronze_ext_location
URL 'abfss://bronze@projectsto.dfs.core.windows.net/bronze'
WITH (STORAGE CREDENTIAL bronze_cred);

# %%
# %sql
CREATE EXTERNAL LOCATION silver_ext_location
URL 'abfss://bronze@projectsto.dfs.core.windows.net/silver'
WITH (STORAGE CREDENTIAL silver_cred);

# %%
# %sql
CREATE EXTERNAL LOCATION gold_ext_location
URL 'abfss://bronze@projectsto.dfs.core.windows.net/gold'
WITH (STORAGE CREDENTIAL gold_cred);
